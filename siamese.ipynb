# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import random
from PIL import Image
import PIL.ImageOps

import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
import torchvision.utils
import torch
from torch.autograd import Variable
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %%
def imshow(img, text=None):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})

    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %%
class SiameseNetworkDataset(Dataset):
    def __init__(self,imageFolderDataset,transform=None):
        self.imageFolderDataset = imageFolderDataset
        self.transform = transform

    def __getitem__(self,index):
        img0_tuple = random.choice(self.imageFolderDataset.imgs)

        #We need to approximately 50% of images to be in the same class
        should_get_same_class = random.randint(0,1)
        if should_get_same_class:
            while True:
                #Look untill the same class image is found
                img1_tuple = random.choice(self.imageFolderDataset.imgs)
                if img0_tuple[1] == img1_tuple[1]:
                    break
        else:

            while True:
                #Look untill a different class image is found
                img1_tuple = random.choice(self.imageFolderDataset.imgs)
                if img0_tuple[1] != img1_tuple[1]:
                    break

        img0 = Image.open(img0_tuple[0])
        img1 = Image.open(img1_tuple[0])

        img0 = img0.convert("L")
        img1 = img1.convert("L")

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)

        return img0, img1, torch.from_numpy(np.array([int(img1_tuple[1] != img0_tuple[1])], dtype=np.float32))

    def __len__(self):
        return len(self.imageFolderDataset.imgs)

# %%
# !wget https://github.com/maticvl/dataHacker/raw/master/DATA/at%26t.zip
# !rm -rf data
# !unzip "at&t.zip" -d att
# Out:
# --2023-08-23 21:05:37--  https://github.com/maticvl/dataHacker/raw/master/DATA/at%26t.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/maticvl/dataHacker/master/DATA/at%26t.zip [following]
# --2023-08-23 21:05:37--  https://raw.githubusercontent.com/maticvl/dataHacker/master/DATA/at%26t.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3797060 (3.6M) [application/zip]
# Saving to: ‘at&t.zip.1’
#
# at&t.zip.1          100%[===================>]   3.62M  --.-KB/s    in 0.07s
#
# 2023-08-23 21:05:37 (52.5 MB/s) - ‘at&t.zip.1’ saved [3797060/3797060]
#
# Archive:  at&t.zip
#    creating: att/data/
#    creating: att/data/faces/
#    creating: att/data/faces/testing/
#    creating: att/data/faces/testing/s5/
#   inflating: att/data/faces/testing/s5/1.pgm
#   inflating: att/data/faces/testing/s5/10.pgm
#   inflating: att/data/faces/testing/s5/2.pgm
#   inflating: att/data/faces/testing/s5/3.pgm
#   inflating: att/data/faces/testing/s5/4.pgm
#   inflating: att/data/faces/testing/s5/5.pgm
#   inflating: att/data/faces/testing/s5/6.pgm
#   inflating: att/data/faces/testing/s5/7.pgm
#   inflating: att/data/faces/testing/s5/8.pgm
#   inflating: att/data/faces/testing/s5/9.pgm
#    creating: att/data/faces/testing/s6/
#   inflating: att/data/faces/testing/s6/1.pgm
#   inflating: att/data/faces/testing/s6/10.pgm
#   inflating: att/data/faces/testing/s6/2.pgm
#   inflating: att/data/faces/testing/s6/3.pgm
#   inflating: att/data/faces/testing/s6/4.pgm
#   inflating: att/data/faces/testing/s6/5.pgm
#   inflating: att/data/faces/testing/s6/6.pgm
#   inflating: att/data/faces/testing/s6/7.pgm
#   inflating: att/data/faces/testing/s6/8.pgm
#   inflating: att/data/faces/testing/s6/9.pgm
#    creating: att/data/faces/testing/s7/
#   inflating: att/data/faces/testing/s7/1.pgm
#   inflating: att/data/faces/testing/s7/10.pgm
#   inflating: att/data/faces/testing/s7/2.pgm
#   inflating: att/data/faces/training/s8/10.pgm
#   inflating: att/data/faces/training/s8/2.pgm
#   inflating: att/data/faces/training/s8/3.pgm
#   inflating: att/data/faces/training/s8/4.pgm
#   inflating: att/data/faces/training/s8/5.pgm
#   inflating: att/data/faces/training/s8/6.pgm
#   inflating: att/data/faces/training/s8/7.pgm
#   inflating: att/data/faces/training/s8/8.pgm
#   inflating: att/data/faces/training/s8/9.pgm
#    creating: att/data/faces/training/s9/
#   inflating: att/data/faces/training/s9/1.pgm
#   inflating: att/data/faces/training/s9/10.pgm
#   inflating: att/data/faces/training/s9/2.pgm
#   inflating: att/data/faces/training/s9/3.pgm
#   inflating: att/data/faces/training/s9/4.pgm
#   inflating: att/data/faces/training/s9/5.pgm
#   inflating: att/data/faces/training/s9/6.pgm
#   inflating: att/data/faces/training/s9/7.pgm
#   inflating: att/data/faces/training/s9/8.pgm
#   inflating: att/data/faces/training/s9/9.pgm

# %%
# !rm -rf data
# !unzip "training.zip" -d .
# Out:
# Archive:  training.zip
#    creating: ./training/abhijot/
#   inflating: ./training/abhijot/faces0_DDFS9409.JPG
#   inflating: ./training/abhijot/faces0_IMG_1264.JPG
#   inflating: ./training/abhijot/faces0_IMG_1312.JPG
#   inflating: ./training/abhijot/faces0_IMG_2093.JPG
#   inflating: ./training/abhijot/faces0_IMG_2094.JPG
#   inflating: ./training/abhijot/faces0_IMG_2096.JPG
#   inflating: ./training/abhijot/faces0_IMG_2157.JPG
#   inflating: ./training/abhijot/faces0_IMG_2159.JPG
#   inflating: ./training/abhijot/faces0_IMG_2160.JPG
#   inflating: ./training/abhijot/faces1_IMG_2153.JPG
#   inflating: ./training/abhijot/faces1_IMG_2155.JPG
#   inflating: ./training/abhijot/faces1_IMG_2156.JPG
#   inflating: ./training/abhijot/faces1_IMG_2158.JPG
#   inflating: ./training/abhijot/faces1_IMG_2755.JPG
#   inflating: ./training/abhijot/faces1_IMG_2756.JPG
#   inflating: ./training/abhijot/faces2_IMG_1263.JPG
#   inflating: ./training/abhijot/faces2_IMG_2154.JPG
#   inflating: ./training/abhijot/faces3_IMG_1265.JPG
#   inflating: ./training/abhijot/faces3_IMG_2757.JPG
#    creating: ./training/Anirudh/
#   inflating: ./training/Anirudh/faces0_IMG_2755.JPG
#   inflating: ./training/Anirudh/faces0_IMG_2756.JPG
#   inflating: ./training/Anirudh/faces0_IMG_2758.JPG
#   inflating: ./training/Anirudh/faces1_IMG_2757.JPG
#    creating: ./training/Ankushdeep/
#   inflating: ./training/Ankushdeep/faces0_IMG_2315.JPG
#   inflating: ./training/Ankushdeep/faces0_IMG_2316.JPG
#   inflating: ./training/Ankushdeep/faces1_IMG_1272.JPG
#   inflating: ./training/Ankushdeep/faces1_IMG_2094.JPG
#   inflating: ./training/Ankushdeep/faces1_IMG_2154.JPG
#   inflating: ./training/Ankushdeep/faces2_IMG_1265.JPG
#   inflating: ./training/Ankushdeep/faces2_IMG_2153.JPG
#   inflating: ./training/Ankushdeep/faces2_IMG_2155.JPG
#   inflating: ./training/Ankushdeep/faces2_IMG_2156.JPG
#   inflating: ./training/Ankushdeep/faces4_IMG_1267.JPG
#    creating: ./training/Armaan/
#   inflating: ./training/Armaan/faces0_IMG_1269.JPG
#   inflating: ./training/Armaan/faces0_IMG_1272.JPG
#   inflating: ./training/Armaan/faces0_IMG_1316.JPG
#   inflating: ./training/Armaan/faces0_IMG_2153.JPG
#   inflating: ./training/Armaan/faces0_IMG_2154.JPG
#   inflating: ./training/Armaan/faces0_IMG_2155.JPG
#   inflating: ./training/Armaan/faces0_IMG_2156.JPG
#   inflating: ./training/Armaan/faces0_IMG_2267.JPG
#   inflating: ./training/Armaan/faces1_DDFS9409.JPG
#   inflating: ./training/Armaan/faces2_IMG_1264.JPG
#   inflating: ./training/Armaan/faces3_IMG_1263.JPG
#   inflating: ./training/Armaan/faces3_IMG_1267.JPG
#   inflating: ./training/Armaan/faces3_IMG_1268.JPG
#   inflating: ./training/Armaan/faces4_IMG_1265.JPG
#   inflating: ./training/Armaan/faces4_IMG_1266.JPG
#    creating: ./training/Arshjeet/
#   inflating: ./training/Arshjeet/faces0_IMG_1263.JPG
#   inflating: ./training/Arshjeet/faces0_IMG_1265.JPG
#   inflating: ./training/Arshjeet/faces0_IMG_1266.JPG
#   inflating: ./training/Arshjeet/faces1_IMG_1264.JPG
#   inflating: ./training/Arshjeet/faces1_IMG_1268.JPG
#   inflating: ./training/Arshjeet/faces2_IMG_1267.JPG
#    creating: ./training/Gurjant/
#   inflating: ./training/Gurjant/faces0_IMG_2270.JPG
#    creating: ./training/Himmat/
#   inflating: ./training/Himmat/faces0_IMG_2158.JPG
#   inflating: ./training/Himmat/faces1_IMG_1263.JPG
#   inflating: ./training/Himmat/faces1_IMG_1265.JPG
#   inflating: ./training/Himmat/faces1_IMG_1267.JPG
#   inflating: ./training/Himmat/faces1_IMG_2093.JPG
#   inflating: ./training/Himmat/faces1_IMG_2157.JPG
#   inflating: ./training/Himmat/faces1_IMG_2159.JPG
#   inflating: ./training/Himmat/faces2_IMG_1268.JPG
#   inflating: ./training/Himmat/faces3_IMG_1264.JPG
#   inflating: ./training/Himmat/faces3_IMG_1266.JPG
#   inflating: ./training/Himmat/faces3_IMG_2153.JPG
#    creating: ./training/Manamrit/
#   inflating: ./training/Manamrit/faces0_IMG_1267.JPG
#   inflating: ./training/Manamrit/faces0_IMG_1268.JPG
#   inflating: ./training/Manamrit/faces2_IMG_1266.JPG
#   inflating: ./training/Manamrit/faces4_IMG_1263.JPG
#    creating: ./training/Nitanshu/
#   inflating: ./training/Nitanshu/faces0_IMG_2757.JPG
#   inflating: ./training/Nitanshu/faces2_IMG_2756.JPG
#   inflating: ./training/Nitanshu/faces3_IMG_2758.JPG
#    creating: ./training/Sehaj/
#   inflating: ./training/Sehaj/faces0_IMG_2162.JPG
#   inflating: ./training/Sehaj/faces0_IMG_2792.JPG
#   inflating: ./training/Sehaj/faces0_IMG_2795.JPG
#   inflating: ./training/Sehaj/faces0_IMG_2802.JPG
#   inflating: ./training/Sehaj/faces1_IMG_1266.JPG
#   inflating: ./training/Sehaj/faces1_IMG_1269.JPG
#   inflating: ./training/Sehaj/faces1_IMG_2096.JPG
#   inflating: ./training/Sehaj/faces1_IMG_2249.JPG
#   inflating: ./training/Sehaj/faces1_IMG_2758.JPG
#   inflating: ./training/Sehaj/faces2_DDFS9409.JPG
#   inflating: ./training/Sehaj/faces2_IMG_2755.JPG
#   inflating: ./training/Sehaj/faces2_IMG_2757.JPG
#   inflating: ./training/Sehaj/faces4_IMG_1268.JPG
#   inflating: ./training/Sehaj/faces5_IMG_1267.JPG

# %%
folder_dataset = datasets.ImageFolder(root="/content/att/data/faces/training")

# %%
transformation = transforms.Compose([transforms.Resize((100,100)),
                                     transforms.ToTensor()
                                    ])

siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset,
                                        transform=transformation)

# %%
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=2,
                        batch_size=8)

# Extract one batch
example_batch = next(iter(vis_dataloader))

# Example batch is a list containing 2x8 images, indexes 0 and 1, an also the label
# If the label is 1, it means that it is not the same person, label is 0, same person in both images
concatenated = torch.cat((example_batch[0], example_batch[1]),0)

imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy().reshape(-1))
# Out:
# [1. 0. 0. 1. 1. 0. 1. 1.]

# %%
class SiameseNetwork(nn.Module):

    def __init__(self):
        super(SiameseNetwork, self).__init__()

        # Setting up the Sequential of CNN Layers
        self.cnn1 = nn.Sequential(
            nn.Conv2d(1, 96, kernel_size=11,stride=4),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(3, stride=2),

            nn.Conv2d(96, 256, kernel_size=5, stride=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, stride=2),

            nn.Conv2d(256, 384, kernel_size=3,stride=1),
            nn.ReLU(inplace=True)
        )

        # Setting up the Fully Connected Layers
        self.fc1 = nn.Sequential(
            nn.Linear(384, 1024),
            nn.ReLU(inplace=True),

            nn.Linear(1024, 256),
            nn.ReLU(inplace=True),

            nn.Linear(256,2)
        )

    def forward_once(self, x):
        # This function will be called for both images
        # It's output is used to determine the similiarity
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        # In this function we pass in both images and obtain both vectors
        # which are returned
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)

        return output1, output2

# %%
class ContrastiveLoss(torch.nn.Module):
    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
      # Calculate the euclidian distance and calculate the contrastive loss
      euclidean_distance = F.pairwise_distance(output1, output2, keepdim = True)

      loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                    (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


      return loss_contrastive

# %%
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=64)

# %%
net = SiameseNetwork().cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(), lr = 0.0005 )

# %%
counter = []
loss_history = []
iteration_number= 0

# Iterate throught the epochs
for epoch in range(100):

    # Iterate over batches
    for i, (img0, img1, label) in enumerate(train_dataloader, 0):

        # Send the images and labels to CUDA
        img0, img1, label = img0.cuda(), img1.cuda(), label.cuda()

        # Zero the gradients
        optimizer.zero_grad()

        # Pass in the two images into the network and obtain two outputs
        output1, output2 = net(img0, img1)

        # Pass the outputs of the networks and label into the loss function
        loss_contrastive = criterion(output1, output2, label)

        # Calculate the backpropagation
        loss_contrastive.backward()

        # Optimize
        optimizer.step()

        # Every 10 batches print out the loss
        if i % 10 == 0 :
            print(f"Epoch number {epoch}\n Current loss {loss_contrastive.item()}\n")
            iteration_number += 10

            counter.append(iteration_number)
            loss_history.append(loss_contrastive.item())

show_plot(counter, loss_history)
# Out:
# Epoch number 0
#  Current loss 2.1854350566864014
#
# Epoch number 1
#  Current loss 0.9180809855461121
#
# Epoch number 2
#  Current loss 0.8197103142738342
#
# Epoch number 3
#  Current loss 0.6026675701141357
#
# Epoch number 4
#  Current loss 0.9248383641242981
#
# Epoch number 5
#  Current loss 0.6658843159675598
#
# Epoch number 6
#  Current loss 0.446817547082901
#
# Epoch number 7
#  Current loss 0.4312504529953003
#
# Epoch number 8
#  Current loss 0.39905643463134766
#
# Epoch number 9
#  Current loss 0.6547256112098694
#
# Epoch number 10
#  Current loss 0.581383228302002
#
# Epoch number 11
#  Current loss 0.4428832232952118
#
# Epoch number 12
#  Current loss 0.5158800482749939
#
# Epoch number 13
#  Current loss 0.5082418322563171
#
# Epoch number 14
#  Current loss 0.46627557277679443
#
# Epoch number 15
#  Current loss 0.40179765224456787
#
# Epoch number 16
#  Current loss 0.36036500334739685
#
# Epoch number 17
#  Current loss 0.4814203977584839
#
# Epoch number 18
#  Current loss 0.3285565972328186
#
# Epoch number 19
#  Current loss 0.3501930832862854
#
# Epoch number 20
#  Current loss 0.31026238203048706
#
# Epoch number 21
#  Current loss 0.2098337858915329
#
# Epoch number 22
#  Current loss 0.32527390122413635
#
# Epoch number 23
#  Current loss 0.13219256699085236
#
# Epoch number 24
#  Current loss 0.35731232166290283
#
# Epoch number 25
#  Current loss 0.327968567609787
#
# Epoch number 26
#  Current loss 0.19565770030021667
#
# Epoch number 27
#  Current loss 0.18977996706962585
#
# Epoch number 28
#  Current loss 0.2627289593219757
#
# Epoch number 29
#  Current loss 0.24409586191177368
#
# Epoch number 30
#  Current loss 0.16010744869709015
#
# Epoch number 31
#  Current loss 0.27004164457321167
#
# Epoch number 32
#  Current loss 0.13467681407928467
#
# Epoch number 33
#  Current loss 0.19222846627235413
#
# Epoch number 34
#  Current loss 0.139940544962883
#
# Epoch number 35
#  Current loss 0.23294782638549805
#
# Epoch number 36
#  Current loss 0.1716197282075882
#
# Epoch number 37
#  Current loss 0.12047500908374786
#
# Epoch number 38
#  Current loss 0.08246560394763947
#
# Epoch number 39
#  Current loss 0.25815334916114807
#
# Epoch number 40
#  Current loss 0.1314520239830017
#
# Epoch number 41
#  Current loss 0.0971129834651947
#
# Epoch number 42
#  Current loss 0.17249695956707
#
# Epoch number 43
#  Current loss 0.15960611402988434
#
# Epoch number 44
#  Current loss 0.15110620856285095
#
# Epoch number 45
#  Current loss 0.10229017585515976
#
# Epoch number 46
#  Current loss 0.09523104876279831
#
# Epoch number 47
#  Current loss 0.1562085747718811
#
# Epoch number 48
#  Current loss 0.08054472506046295
#
# Epoch number 49
#  Current loss 0.07661816477775574
#
# Epoch number 50
#  Current loss 0.13591349124908447
#
# Epoch number 51
#  Current loss 0.15044459700584412
#
# Epoch number 52
#  Current loss 0.07394920289516449
#
# Epoch number 53
#  Current loss 0.06074529513716698
#
# Epoch number 54
#  Current loss 0.06053011864423752
#
# Epoch number 55
#  Current loss 0.07804656028747559
#
# Epoch number 56
#  Current loss 0.08600683510303497
#
# Epoch number 57
#  Current loss 0.1346818506717682
#
# Epoch number 58
#  Current loss 0.11716059595346451
#
# Epoch number 59
#  Current loss 0.06816629320383072
#
# Epoch number 60
#  Current loss 0.07402023673057556
#
# Epoch number 61
#  Current loss 0.06165799871087074
#
# Epoch number 62
#  Current loss 0.06890086829662323
#
# Epoch number 63
#  Current loss 0.09310951828956604
#
# Epoch number 64
#  Current loss 0.04216117411851883
#
# Epoch number 65
#  Current loss 0.04978277534246445
#
# Epoch number 66
#  Current loss 0.05137472599744797
#
# Epoch number 67
#  Current loss 0.09908835589885712
#
# Epoch number 68
#  Current loss 0.09045445173978806
#
# Epoch number 69
#  Current loss 0.056089602410793304
#
# Epoch number 70
#  Current loss 0.08398616313934326
#
# Epoch number 71
#  Current loss 0.03173524886369705
#
# Epoch number 72
#  Current loss 0.04138360172510147
#
# Epoch number 73
#  Current loss 0.04116228222846985
#
# Epoch number 74
#  Current loss 0.03158969804644585
#
# Epoch number 75
#  Current loss 0.039889462292194366
#
# Epoch number 76
#  Current loss 0.043634165078401566
#
# Epoch number 77
#  Current loss 0.020272230729460716
#
# Epoch number 78
#  Current loss 0.040211815387010574
#
# Epoch number 79
#  Current loss 0.05571087449789047
#
# Epoch number 80
#  Current loss 0.032368458807468414
#
# Epoch number 81
#  Current loss 0.0665731281042099
#
# Epoch number 82
#  Current loss 0.041889503598213196
#
# Epoch number 83
#  Current loss 0.03653024137020111
#
# Epoch number 84
#  Current loss 0.04311148822307587
#
# Epoch number 85
#  Current loss 0.02365877479314804
#
# Epoch number 86
#  Current loss 0.04443592578172684
#
# Epoch number 87
#  Current loss 0.06153019890189171
#
# Epoch number 88
#  Current loss 0.021104373037815094
#
# Epoch number 89
#  Current loss 0.047256577759981155
#
# Epoch number 90
#  Current loss 0.019219325855374336
#
# Epoch number 91
#  Current loss 0.02868659421801567
#
# Epoch number 92
#  Current loss 0.02207152545452118
#
# Epoch number 93
#  Current loss 0.018347185105085373
#
# Epoch number 94
#  Current loss 0.020979318767786026
#
# Epoch number 95
#  Current loss 0.04617181420326233
#
# Epoch number 96
#  Current loss 0.041651561856269836
#
# Epoch number 97
#  Current loss 0.03166628256440163
#
# Epoch number 98
#  Current loss 0.02094532921910286
#
# Epoch number 99
#  Current loss 0.029548045247793198

# %%
folder_dataset_test = datasets.ImageFolder(root="/content/att/data/faces/testing")
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
                                        transform=transformation)
test_dataloader = DataLoader(siamese_dataset, num_workers=2, batch_size=1, shuffle=True)

# Grab one image that we are going to test
dataiter = iter(test_dataloader)
x0, _, _ = next(dataiter)

for i in range(10):
    # Iterate over 10 images and test them with the first image (x0)
    _, x1, label2 = next(dataiter)

    # Concatenate the two images together
    concatenated = torch.cat((x0, x1), 0)

    output1, output2 = net(x0.cuda(), x1.cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated), f'Dissimilarity: {euclidean_distance.item():.2f}')
